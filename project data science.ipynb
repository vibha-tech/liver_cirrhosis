# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn as sklearn
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\vibha\Documents\liver_cirrhosis_dataset.csv")

# %%
df
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %%
df.shape
# Out:
# (25000, 19)

# %%
df.columns
# Out:
# Index(['N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites', 'Hepatomegaly',
#        'Spiders', 'Edema', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
#        'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin',
#        'Stage'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         25000 non-null  int64
#  1   Status         25000 non-null  object
#  2   Drug           25000 non-null  object
#  3   Age            25000 non-null  int64
#  4   Sex            25000 non-null  object
#  5   Ascites        25000 non-null  object
#  6   Hepatomegaly   25000 non-null  object
#  7   Spiders        25000 non-null  object
#  8   Edema          25000 non-null  object
#  9   Bilirubin      25000 non-null  float64
#  10  Cholesterol    25000 non-null  float64
#  11  Albumin        25000 non-null  float64
#  12  Copper         25000 non-null  float64
#  13  Alk_Phos       25000 non-null  float64
#  14  SGOT           25000 non-null  float64
#  15  Tryglicerides  25000 non-null  float64
#  16  Platelets      25000 non-null  float64
# ...

# %%
df.describe()
# Out:
#              N_Days           Age     Bilirubin   Cholesterol       Albumin  \
# count  25000.000000  25000.000000  25000.000000  25000.000000  25000.000000
# mean    1887.117040  18495.877080      3.402644    372.331471      3.486578
# std     1091.690918   3737.596616      4.707491    193.668452      0.380488
# min       41.000000   9598.000000      0.300000    120.000000      1.960000
# 25%     1080.000000  15694.000000      0.800000    275.000000      3.290000
# 50%     1680.000000  18499.000000      1.300000    369.510563      3.510000
# 75%     2576.000000  20955.000000      3.400000    369.510563      3.750000
# max     4795.000000  28650.000000     28.000000   1775.000000      4.640000
#
#              Copper      Alk_Phos          SGOT  Tryglicerides     Platelets  \
# count  25000.000000  25000.000000  25000.000000   25000.000000  25000.000000
# mean     100.184663   1995.675597    123.166345     123.822548    256.007337
# ...

# %%
#EDA

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Status          object
# Drug            object
# Sex             object
# Ascites         object
# Hepatomegaly    object
# Spiders         object
# Edema           object
# dtype: object

# %% [markdown]
# ## Distribution of numerical features

# %%
df.hist(figsize=(20,20), xrot=-45,bins=10)
plt.show()

# %%
df.isnull().sum()
# Out:
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %%
df
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %%
df.Status.value_counts()
# Out:
# Status
# C     13516
# D      9456
# CL     2028
# Name: count, dtype: int64

# %%
df.Drug.value_counts()
# Out:
# Drug
# Placebo            15827
# D-penicillamine     9173
# Name: count, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# Sex
# F    22137
# M     2863
# Name: count, dtype: int64

# %%
df.Spiders.value_counts()
# Out:
# Spiders
# N    13614
# Y    11386
# Name: count, dtype: int64

# %%
df.Ascites.value_counts()
# Out:
# Ascites
# N    16798
# Y     8202
# Name: count, dtype: int64

# %%
df.Hepatomegaly.value_counts()
# Out:
# Hepatomegaly
# N    15243
# Y     9757
# Name: count, dtype: int64

# %%
df.Edema.value_counts()
# Out:
# Edema
# N    20220
# S     3698
# Y     1082
# Name: count, dtype: int64

# %%
#encoding the dataset

# %%
y = df['Status'].values
y
# Out:
# array(['C', 'C', 'C', ..., 'D', 'C', 'C'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
df
# Out:
#        N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0        2221      C          Placebo  18499   F       N            Y       N
# 1        1230      C          Placebo  19724   M       Y            N       Y
# 2        4184      C          Placebo  11839   F       N            N       N
# 3        2090      D          Placebo  16467   F       N            N       N
# 4        2105      D          Placebo  21699   F       N            Y       N
# ...       ...    ...              ...    ...  ..     ...          ...     ...
# 24995    3584      D  D-penicillamine  23612   F       N            N       N
# 24996    3584      D  D-penicillamine  23612   F       N            N       N
# 24997     971      D  D-penicillamine  16736   F       N            Y       Y
# 24998    3707      C  D-penicillamine  16990   F       N            Y       N
# 24999    3707      C  D-penicillamine  16990   F       N            Y       N
#
# ...

# %%
df["Status"] = y

# %%
z = df['Drug'].values
z
# Out:
# array(['Placebo', 'Placebo', 'Placebo', ..., 'D-penicillamine',
#        'D-penicillamine', 'D-penicillamine'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
z = le.fit_transform(z)

# %%
z
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
df["Drug"] = z
df
# Out:
#        N_Days  Status  Drug    Age Sex Ascites Hepatomegaly Spiders Edema  \
# 0        2221       0     1  18499   F       N            Y       N     N
# 1        1230       0     1  19724   M       Y            N       Y     N
# 2        4184       0     1  11839   F       N            N       N     N
# 3        2090       2     1  16467   F       N            N       N     N
# 4        2105       2     1  21699   F       N            Y       N     N
# ...       ...     ...   ...    ...  ..     ...          ...     ...   ...
# 24995    3584       2     0  23612   F       N            N       N     N
# 24996    3584       2     0  23612   F       N            N       N     N
# 24997     971       2     0  16736   F       N            Y       Y     Y
# 24998    3707       0     0  16990   F       N            Y       N     N
# 24999    3707       0     0  16990   F       N            Y       N     N
#
#        Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
x = df['Sex'].values
x
# Out:
# array(['F', 'M', 'F', ..., 'F', 'F', 'F'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x = le.fit_transform(x)

# %%
x
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
df["Sex"] = x
df
# Out:
#        N_Days  Status  Drug    Age  Sex Ascites Hepatomegaly Spiders Edema  \
# 0        2221       0     1  18499    0       N            Y       N     N
# 1        1230       0     1  19724    1       Y            N       Y     N
# 2        4184       0     1  11839    0       N            N       N     N
# 3        2090       2     1  16467    0       N            N       N     N
# 4        2105       2     1  21699    0       N            Y       N     N
# ...       ...     ...   ...    ...  ...     ...          ...     ...   ...
# 24995    3584       2     0  23612    0       N            N       N     N
# 24996    3584       2     0  23612    0       N            N       N     N
# 24997     971       2     0  16736    0       N            Y       Y     Y
# 24998    3707       0     0  16990    0       N            Y       N     N
# 24999    3707       0     0  16990    0       N            Y       N     N
#
#        Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
p = df['Ascites'].values
p
# Out:
# array(['N', 'Y', 'N', ..., 'N', 'N', 'N'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
p = le.fit_transform(p)

# %%
p
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
df["Ascites"] = p
df
# Out:
#        N_Days  Status  Drug    Age  Sex  Ascites Hepatomegaly Spiders Edema  \
# 0        2221       0     1  18499    0        0            Y       N     N
# 1        1230       0     1  19724    1        1            N       Y     N
# 2        4184       0     1  11839    0        0            N       N     N
# 3        2090       2     1  16467    0        0            N       N     N
# 4        2105       2     1  21699    0        0            Y       N     N
# ...       ...     ...   ...    ...  ...      ...          ...     ...   ...
# 24995    3584       2     0  23612    0        0            N       N     N
# 24996    3584       2     0  23612    0        0            N       N     N
# 24997     971       2     0  16736    0        0            Y       Y     Y
# 24998    3707       0     0  16990    0        0            Y       N     N
# 24999    3707       0     0  16990    0        0            Y       N     N
#
# ...

# %%
q = df['Hepatomegaly'].values
q
# Out:
# array(['Y', 'N', 'N', ..., 'Y', 'Y', 'Y'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
q = le.fit_transform(q)

# %%
q
# Out:
# array([1, 0, 0, ..., 1, 1, 1])

# %%
df["Hepatomegaly"] = q
df
# Out:
#        N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly Spiders Edema  \
# 0        2221       0     1  18499    0        0             1       N     N
# 1        1230       0     1  19724    1        1             0       Y     N
# 2        4184       0     1  11839    0        0             0       N     N
# 3        2090       2     1  16467    0        0             0       N     N
# 4        2105       2     1  21699    0        0             1       N     N
# ...       ...     ...   ...    ...  ...      ...           ...     ...   ...
# 24995    3584       2     0  23612    0        0             0       N     N
# 24996    3584       2     0  23612    0        0             0       N     N
# 24997     971       2     0  16736    0        0             1       Y     Y
# 24998    3707       0     0  16990    0        0             1       N     N
# 24999    3707       0     0  16990    0        0             1       N     N
#
# ...

# %%
r = df['Spiders'].values
r
# Out:
# array(['N', 'Y', 'N', ..., 'Y', 'N', 'N'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
r = le.fit_transform(r)

# %%
r
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
df["Spiders"] = r
df
# Out:
#        N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders Edema  \
# 0        2221       0     1  18499    0        0             1        0     N
# 1        1230       0     1  19724    1        1             0        1     N
# 2        4184       0     1  11839    0        0             0        0     N
# 3        2090       2     1  16467    0        0             0        0     N
# 4        2105       2     1  21699    0        0             1        0     N
# ...       ...     ...   ...    ...  ...      ...           ...      ...   ...
# 24995    3584       2     0  23612    0        0             0        0     N
# 24996    3584       2     0  23612    0        0             0        0     N
# 24997     971       2     0  16736    0        0             1        1     Y
# 24998    3707       0     0  16990    0        0             1        0     N
# 24999    3707       0     0  16990    0        0             1        0     N
#
# ...

# %%
s = df['Edema'].values
s
# Out:
# array(['N', 'N', 'N', ..., 'Y', 'N', 'N'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
s = le.fit_transform(s)

# %%
s
# Out:
# array([0, 0, 0, ..., 2, 0, 0])

# %%
df["Edema"] = s
df
# Out:
#        N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0        2221       0     1  18499    0        0             1        0
# 1        1230       0     1  19724    1        1             0        1
# 2        4184       0     1  11839    0        0             0        0
# 3        2090       2     1  16467    0        0             0        0
# 4        2105       2     1  21699    0        0             1        0
# ...       ...     ...   ...    ...  ...      ...           ...      ...
# 24995    3584       2     0  23612    0        0             0        0
# 24996    3584       2     0  23612    0        0             0        0
# 24997     971       2     0  16736    0        0             1        1
# 24998    3707       0     0  16990    0        0             1        0
# 24999    3707       0     0  16990    0        0             1        0
#
#        Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
#splitting dataset into training testing dataset

# %%
x = df.drop("Stage" , axis=1).values
x
# Out:
# array([[2.22100000e+03, 0.00000000e+00, 1.00000000e+00, ...,
#         5.70000000e+01, 2.56000000e+02, 9.90000000e+00],
#        [1.23000000e+03, 0.00000000e+00, 1.00000000e+00, ...,
#         7.50000000e+01, 2.20000000e+02, 1.08000000e+01],
#        [4.18400000e+03, 0.00000000e+00, 1.00000000e+00, ...,
#         8.00000000e+01, 2.25000000e+02, 1.00000000e+01],
#        ...,
#        [9.71000000e+02, 2.00000000e+00, 0.00000000e+00, ...,
#         1.24702128e+02, 1.04000000e+02, 1.30000000e+01],
#        [3.70700000e+03, 0.00000000e+00, 0.00000000e+00, ...,
#         7.00000000e+01, 4.26000000e+02, 1.09000000e+01],
#        [3.70700000e+03, 0.00000000e+00, 0.00000000e+00, ...,
#         7.00000000e+01, 4.26000000e+02, 1.09000000e+01]])

# %%
y=df['Stage'].values
y
# Out:
# array([1, 2, 2, ..., 3, 2, 2], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
[x_train, x_test, y_train, y_test] = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn import linear_model
lin_model = linear_model.LinearRegression()

# %%
lin_model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
linacc = lin_model.score(x_test , y_test)
linacc
# Out:
# 0.30552744574663115

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=3)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knnacc = knn_model.score(x_test , y_test)
knnacc
# Out:
# 0.667505216894952

# %%
plt.bar(['Linear Regression' , 'KNN'],[linacc*100 , knnacc*100] , width=0.4 ,edgecolor='black',
        linewidth=2.5)
plt.title("Comparing Accuracy of models")
plt.ylabel("Accuracy Percentage" , fontsize=14)
plt.ylim(0,100)
plt.show()
